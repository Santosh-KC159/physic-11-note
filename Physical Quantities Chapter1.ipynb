# %% [markdown]
# ## Chaper 1
#
# ### Physical Quantities
#
# ##### Introduction
#
# Physics is branch of natural science which deals about nature and formulates the natural phenomena in mathematical forms.It is quantitative science.It makes use of verious mathematical concepts to explain the natural laws and experimentally observed facts.
#
# The field of physics is usually divided into many branches such as Mechanics,Optics,Heat,Electricity and so on.
#
# ###### Mechanics:
#
# Mechanics is branch of physics that deals with body either at rest or in motion.It is the guiding principle for all other branches of physics.In general,it is the grammar of physics.
# Mechanics is classified into two classes:(i) Statics and(ii)Kinetics
#
# ###### Statics:
#
# Statics is the branch of mechanics that deals with a body at rest.
#
# ###### Kinetics
#
# Kinetics is the branch of mechanics that deals with body at motion.
#
# kinetics is further divides into two types:(i)Kinematics and(ii)Dynamics
#
#
# ###### Kinamatics
#
# Kinamatics is branch of mechanics that deals with body in motions without taking into account the cause of motion.
#
# ###### Dynamics
#
# Dynamics is the branch of mechanics that deals with the body in motion taking into account the cause of motion.

# %% [markdown]
# ## Physical Quantity
#
# A physical quantity is a property of a material or system that can be quantified by measurement. A physical quantity can be expressed as the combination of a numerical value and a unit. For example, the physical quantity mass can be quantified as n kg, where n is the numerical value and kg is the unit.A physical quantity possesses at least two characteristics in common, one is numerical magnitude and other is the unit in which it is measured.(https://en.wikipedia.org/wiki/Physical_quantity)
#
# So,a physical quantity is expressed as;
#
# Physical quantity =Magnitude * unit
#
#                   = Numerical value * unit
#
#                   = N * U
#
# All physical quantities are boardly divided in to two sorts:(i) Fundamental quantity (ii)Derived quantity
#
# #### Fundamental Quantity
#
# The basic physical quantity which is taken as a standard to measure other physical quantities is known as fundamental quantity.They are independent and helps drive the other physical quantities.They are length,mass and time(Mechanics); liminous intensity(Optics); temperature(Heat); electric current(Electricity) and amount of chemical subatance(Nuclear Physics).
#
# In addition,there are two sub-fundamental quantities such as plane angle and solid angle.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Derived Qunatity
#
# The physical quantities which can be expressed in terms of fundamental quantity is known as derived physical quantity i.e.
# a quantity obtained from fundamental quantities is called derived quantity..Area, volume, density, speed, electric intensity etc are some example of derived quantity.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Dimension, Dimensional Formula and Dimensional Equation
#
# The dimension of a physical quantity can be defined as the power raised to the fundamental qunatities invoved in the derived physical quantity i.e. it may be defined as the number of times the fundamental units of mass, length and time appear in the physical quantity.Obiviously,dimensions of physical quantities tell us which basic quantities are involved and how many times they came in the given quantity.
#
# An expression which shows how and which basic quantities are involved in the derived quantity is called dimensional formula of that quantity.It is generally written in square bracket [].
#
# An equation obtained by equating a physical quantity with is dimeensional formula is called dimensional equation of the physical quantity.
#
# The basic quantities with their symbols in square brakets are as follows:
#
# [Length] =$[L]$            [Mass] =$[M]$         [Time] =$[T]$
#
# [Temperature] =$[K] or [\theta]$ [Electric current] = $[A] or[I]$  [Number of moles]=$ [N] $
#
# ##### Example
#
# Dimensional formula of Force is $[MLT^{-2}]$ and its dimensional equation is written as
#
# $[Force] = [MLT^{-2}]$
#
# The powers 1, 1, and -2 in mass, length, and time of the symbols in brackets represent the dimensions of mass, length and time which indicates that mass, length and time are all involved in force but mass comes one time, length also comes one time and time comes two times in force.
#
#
# Let us take some example of derived quantity and their dimension.$[Mechanics]$
#
# ##### 1. Dimension of Density
#
# ![image.png](attachment:image.png)
#
# Here poewer of $[L]$,$[M]$ and $[T]$ are -3, 1, 0.So,dimensions of density are -3 in Length,1 in mass and 0 in time.

# %% [markdown]
# ##### 2. Dimension of pressure
#
# ![image.png](attachment:image.png)
#
# Here poewer of $[L]$,$[M]$ and $[T]$ are -1, 1, -2.So,dimensions of density are -1 in Length,1 in mass and -2 in time.

# %% [markdown]
# ##### 3.Dimension of Velocity
# ![image.png](attachment:image.png)
#
# Here poewer of $[L]$,$[M]$ and $[T]$ are 1, 0 ,-1.So,dimensions of pressure are 1 in Length,0 in mass and -1 in time.

# %% [markdown]
# #### 4.Dimension of acceleration
# ![image.png](attachment:image.png)
# Here poewer of $[L]$,$[M]$ and $[T]$ are 1, 0, -2.So,dimensions of density are 1 in Length,0 in mass and -2 in time.

# %% [markdown]
# In this way, we can calculate following dimensional formula of physical quantities.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Dimension of permitivity
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ###### Home assignment:
#
# 1.Find the dimensions of planck's constant 'h' from the given equation: $\lambda =\frac{h}{p}; where $\lambda$ is wavelength and $p$ is momentum of photon.
#
# 2.Obtain dimensions of specific heat capacity and gravitational constant.

# %% [markdown]
# ### Arbitrary Basic Quantities
#
# We can choose quantity as a basic quantity in arbitrary manner so the dimensional formula of a quantity can be expressed in new system having basic units different than we have in the actual system of unit.Examples:
#
#     (i) Dimensional formula of length in a system of units in which the basic units are force(F),acceleration(A) and time(T).
#
#  ##### Let $[L] =[F^{a} A^{b} T^{c}]$                        ..............................(i)
#
#   Writting the dimensional formula for different quantities in the conventional quantities M, L, and T,we get
#
#   $[L] = [MLT^{-2}]^{a}[LT^{-2}]^{b}[T^{c}]$
#
#   or,$[M^{0}LT^{0}] = [M^{a}L^{a+b}T^{-2a-2b+c}]$
#
#   Comparing the dimensions on both sides,we get,
#
#  $0 = a$
#
#  $1 = a+b$,
#
#  $0 = -2a-2b+c$
#
#  Soving,we get
#
#  $a = 0$,$b = 1$ and $c=2$
#
#  Inserting these values in equation(i), we get,
#
#  $[L] =[F^{0}AT^{2}]$
#
#
#     (ii) Dimensional formula of mass in which velocity(V), time(T) and force(F) are choosen as basic quantities.[Assignment]

# %% [markdown]
# ###### Principle of homogeneity of dimension:
#
# Principle of Homogeneity states that dimensions of each of the terms of a dimensional equation on both sides should be the same.It means,the dimensions of a physical quantity on either side of physical equation must be equal.
# For example,In the equation, $A+B =C$,if we suppose dimension of A is L,then according to the principle of homogeneity of dimension B and C also have the same dimension i.e.L.
#
# ### Uses of Dimensional Formula
#
# Following are the uses of dimensional formula:
#
# ##### (i) To check the correctness of a physical equation:
#
# A physical eqaution will be correct dimensionally if and only if dimensions of each term on L.H.S. are the same as the dimensions of each term on R.H.S. of the given equation.For example,
#
# ###### (a) $v^{2} = u^{2} +2as$
#
# $[L.H.S] = [v^{2}]$        $ =[LT^{-1}]^{2}$  $ =[L^{2}T^{-2}]$       ..............(i)
#
# $[R.H.S.]=[u^{2}+2as] = [u^{2}]+[2as] $
#
# $=[LT^{-1}]^{2} +2[LT^{-2}][L]  = [L^{2}T^{-2}]+2[L^{2}T^{-2}] $
#
# Since ,the number '2' is dimensionless,
#
# $[R.H.S.] =  [L^{2}T^{-2}]+[L^{2}T^{-2}] $              ....................(ii)
#
# From equations (i) and (ii), we have
#
# $[R.H.S.] = [L.H.S]$
#
# Hence, the given equation is dimensionally correct.
#
# (b) $T=2\pi \sqrt {\frac{l}{g}}$
#
# Dimensions of L.H.S. =$[T]$
#
# $=[M^{0}L^{0}T]$             ................................(iii)
#
# Dimensions of R.H.S. =$[2\pi \sqrt{\frac{l}{g}}]$
#
# =$ [\frac {L}{LT^{-2}}]^{\frac{1}{2}}$
#
# =$[(L^{0}T^{2})^{\frac{1}{2}}]$
#
# =$[L^{0}T]$
#
# =$[M^{0}L^{0}T]$               .........................................(iv)
#
# From equations (iii) and (iv),we get,
#
# $[L.H.S] = [R.H.S]$
#
# Hence,the given equation is dimensionally correct.
#
# ###### question:Check the correctness of the relation $h = \frac {2Tcos\theta}{r \rho g} $,where symbols have usual meaning.
#
# ###### Ans:
#
# Here,given formula is
#
# $h = \frac {2Tcos\theta}{r \rho g} $
#
# $[L.H.S.] =[h] = [L]$               .....................(i)
#
# $[R.H.S] =[\frac{2T cos\theta}{r \rho g}$]
#
# we have,
# $[\rho] =[ML^{-3}]$
#
# $[g] =[LT^{-2}]$
#
# $[T] =[MT^{-2}]$ and  $2cos\theta$ is dimensionless.
#
# Then
#
# $[\frac {2Tcos\theta}{r \rho g}] =[ \frac{MT^{-2}}{[L] [ML^{-3}][LT^{-2}]}]$
#
# =[$L$]                        ...............................(ii)
#
# So the given equation is dimensionally correct.

# %% [markdown]
# ###### Home  assignment
#
# 1.A students writes $\sqrt \frac{R}{2GM}$ for eacape velocity.Check the correctness of formula by using dimensional analysis.
#
# 2.Check the correctness of formula $t =2\pi \sqrt \frac{m}{k} $ where t be the time period,m is mass and k is the force per unit displacement.

# %% [markdown]
# ##### (ii) To deduce the relationship between different physical quantities:
#
# Dimensional method is also used to deduce the relationshop between different physical quantities.For example,
#
# $$ F = \frac {mv^{2}}{r}$$
#
# Where,$F = force$ ,$m = mass$ of a body moving with speed $v$ in a circular path of radius $r$.
#
# It is assumed that,
#
# $$ F \propto m^{a}v^{b}r^{c} $$
#
# $$ \therefore  F= k m^{a}v^{b}r^{c}    ........(i)$$
#
# Writting the dimensions of various quantities in equation(i),we get
#
# $$[MLT^{-2}] = [M]^{a} [LT^{-1}]^{b} [L]^{c} $$
#
# $$            =[M^{a} L^{b+c} T^{-b}] $$
#
# Applying the principle of homogeneity of dimensions,we get,
#
# $$a = 1 $$
#
# $$b+c = 1$$
#
# $$-b = -2    \implies b = 2$$
#
# Also, $$b+c = 1 $$
#
# or, $$ c= -1$$
#
# Inserting these values in equation(i),we get,
#
# $$F= k m^{1}v^{2}r^{-1}$$
#
# or, $$F = k \frac{mv^{2}}{r} $$
#
# $k$ is experimentally found to be 1,So,we can write,
#
# $$ \therefore F = \frac{mv^{2}}{r} $$
#
# This is the required relations.

# %% [markdown]
# ##### (iii) To convert a unit from one system into another:
#
# We consider a physical quantity $X$ which can be expressed interm of magnitude and unit.
#
# In the first system,
#
# $X= N_{1}*U_{1}$
#
# $\therefore X = N_{1}[{M_{1}}^{a}{L_{1}}^{b}{T_{1}}^{c}]$     ............(i)
#
# In another system,
#
# $X= N_{2}*U_{2}$
#
# $\therefore X = N_{2}[{M_{2}}^{a}{L_{2}}^{b}{T_{2}}^{c}]$       ...............(ii)
#
# From equations (i) and (ii),we get,
#
# $N_{1}[{M_{1}}^{a}{L_{1}}^{b}{T_{1}}^{c}] = N_{2}[{M_{2}}^{a}{L_{2}}^{b}{T_{2}}^{c}]$
#
# $ \implies N_{2} = \frac {N_{1}[{M_{1}}^{a}{L_{1}}^{b}{T_{1}}^{c}]}{[{M_{2}}^{a}{L_{2}}^{b}{T_{2}}^{c}]}$
#
# $ \therefore N_{2} =N_{1}[\frac{M_{1}}{M_{2}}]^{a} [\frac{L_{1}}{L_{2}}]^{b} [\frac {T_{1}}{T_{2}}]^{c}$           ..........(iii)
#
# Using this relation,we can convert a unit from one system to another.
#
# ###### Examples:
#
# (a) Convert 1 dyne into newton.
#
# $ Solution$
#
# Let, 1 dyne = $N_{2}$ newton
#
# [ dyne is the unit of force in CGS system and newton is SI unit]
#
# we can write the dimensional formula of force is as,
#
# $$[Force] = [MLT^{-2}]$$
#
# |CGS System    | SI units   |
# |--------------|------------|
# |$$N_{1}=1$$     |$$N_{2}=? $$  |
# |$M_{1}=1 g$   |$M_{2}=1 kg $ |
# |$L_{1}=1 cm$  |$L_{2}=1 m $|
# |$T_{1}=1 s $  |$T_{2}=1 s $  |
#
# Dimensions of force are $a=1$ in mass,$b=1$ in length and $c=-2$ in time.
#
# According to the conversion formula,we have,
#
# $$ N_{2} =N_{1}[\frac{M_{1}}{M_{2}}]^{a} [\frac{L_{1}}{L_{2}}]^{b} [\frac {T_{1}}{T_{2}}]^{c}$$
#
# putting the above values in this equation,we get,
#
# $$ N_{2} = 1[\frac{1 g}{1 kg}]^{1}[\frac{1 cm}{1 m}]^{1}[\frac{1 s}{1 s}]^{-2}$$
#
# $$       = [\frac{1 g}{10^{3} g}]^{1}[\frac{1 cm}{10^{2} cm}]^{1}[\frac{1s}{1s}]^{-2}$$
#
# $$\therefore N_{2} = 10^{-3}*10^{-2}*1 =10^{-5} $$
#
# Hence, 1 dyne = $10^{-5}$ newton.
#
#
# #### Homework
#
# (a) Convert $500$ erg into joule.

# %% [markdown]
# ##### Questions:
#
# 1.A student writes an expression of the force causing a body of mass $(m)$ to move in a circular motion with a velocity $(v)$ as $F = mv^{2}$. Use the dimensional method to check its correctness.
#
#
# 2.Name any two physical quantities which have the same dimensions. Can a quantity have unit but no dimension? Explain.
#
# 3.Time period of oscillating drop of radius $r$,density $\rho$, and surface tension $T$ is $t=k \sqrt \frac {\rho r^{3}}{T}$.Check the correctness of the realation.Given k is dimensionless constant.
#
# 4.

# %% [markdown]
# #### Accuracy and Precision:
#
#
# Accuracy refers to the closeness of a measured value to a standard or known value. For example, if in lab you obtain a weight measurement of 3.2 kg for a given substance, but the actual or known weight is 10 kg, then your measurement is not accurate. In this case, your measurement is not close to the known value.
#
# Precision refers to the closeness of two or more measurements to each other. Using the example above, if you weigh a given substance five times, and get 3.2 kg each time, then your measurement is very precise. Precision is independent of accuracy. You can be very precise but inaccurate, as described above. You can also be accurate but imprecise.
#
# For example, if on average, your measurements for a given substance are close to the known value, but the measurements are far from each other, then you have accuracy without precision.
#
# A good analogy for understanding accuracy and precision is to imagine a basketball player shooting baskets. If the player shoots with accuracy, his aim will always take the ball close to or into the basket. If the player shoots with precision, his aim will always take the ball to the same location which may or may not be close to the basket. A good player will be both accurate and precise by shooting the ball the same way each time and each time making it in the basket.

# %% [markdown]
# #### Significant figures
#
# Significant figures are the number of digits in a value, often a measurement, that contribute to the degree of accuracy of the value. We start counting significant figures at the first non-zero digit.
#
# Here are some examples of significant figure calculations:
#
# $\implies$7 has 1 significant figure (7).
#
# $\implies$73 has 2 significant figures (7 and 3).
#
# $\implies$100 has 1 significant figure (1).
#
# $\implies$673 has 3 significant figures (6, 7 and 3).
#
# $\implies$673.52 has 5 significant figures (6, 3, 7, 5 and 2).
#
# $\implies$0.0637 has 3 significant figures (6, 3 and 7).
#
# $\implies$30.00 has 4 significant figures (3, 0, 0 and 0) and 2 decimals.
#
# $\implies$0.0025 has 2 significant figures (2 and 5) and 4 decimals.
#
# #### Rules for Significant Figures
#
# To determine the number of significant figures in a number use the following 3 rules:
#
# 1.Non-zero digits are always significant.
#
# 2.Any zeros between two significant digits are significant.
#
# 3.A final zero or trailing zeros in the decimal portion ONLY are significant.
#
# Example:  .500 or .632000 the zeros are significant
#
# .006  or .000968 the zeros are NOT significant
#
# ###### For addition and subtraction use the following rules:
#
# Count the number of significant figures in the decimal portion ONLY of each number in the problem
# Add or subtract in the normal fashion
# Your final answer may have no more significant figures to the right of the decimal than the LEAST number of significant figures in any number in the problem.
#
# ###### For multiplication and division use the following rule:
#
# The LEAST number of significant figures in any number of the problem determines the number of significant figures in the answer. (You are now looking at the entire number, not just the decimal portion)
# *This means you have to be able to recognize significant figures in order to use this rule*
#
# Example: 5.26 has 3 significant figures
#
#         6.1 has 2 significant figures
